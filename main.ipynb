# %% [markdown]
# # Importing Dependancies

# %%
# %matplotlib notebook 
# %matplotlib inline

import os
import csv
import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import zipfile
from scipy.stats import linregress
import glob

# %% [markdown]
# # Reading Files & Creating DataFrames

# %%
#Air Quality Index DataFrame
aqi_df = pd.read_csv("../Output/aqi_compiled.csv")

# %%
#Gases DataFrame
co_df = pd.read_csv("../Output/co_compiled.csv")
no2_df = pd.read_csv("../Output/no2_compiled.csv")
ozone_df = pd.read_csv("../Output/ozone_compiled.csv")
so2_df = pd.read_csv("../Output/so2_compiled.csv")

# %%
no2_data = no2_df.loc[(no2_df["State Name"]=="Connecticut")|(no2_df["State Name"]=="New York")|(no2_df["State Name"]=="New Jersey")&(no2_df["Date Local"]>"1/1/2010")]

# %%
no2_data = no2_df.loc[("Date Local", "Latitude", "Longitude", "Observation Count", "Observation Percent", "Arithmetic Mean", "AQI", "State Name","County Name")]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-85-3d172bd94f1c> in <module>
# ----> 1 no2_data = no2_df.loc[("Date Local", "Latitude", "Longitude", "Observation Count", "Observation Percent", "Arithmetic Mean", "AQI", "State Name","County Name")]
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     808
#     809         # no multi-index, so validate all of the indexers
# --> 810         self._has_valid_tuple(tup)
#     811
#     812         # ugly hack for GH #836
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     231         for i, k in enumerate(key):
#     232             if i >= self.obj.ndim:
# --> 233                 raise IndexingError("Too many indexers")
#     234             try:
#     235                 self._validate_key(k, i)
#
# IndexingError: Too many indexers

# %%
no2_data

# %%
no2_data.to_csv("../Output/Summary_no2_data.csv")

# %%
so2_data = so2_df.loc[(so2_df["State Name"]=="Connecticut")|(so2_df["State Name"]=="New York")|(so2_df["State Name"]=="New Jersey")&(so2_df["Date Local"]>"1/1/2010")]

# %%
so2_data
# Out:
#          State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 31916             9            1        12           42401    1  41.195076
# 31917             9            1        12           42401    1  41.195076
# 31918             9            1        12           42401    1  41.195076
# 31919             9            1        12           42401    1  41.195076
# 31920             9            1        12           42401    1  41.195076
# ...             ...          ...       ...             ...  ...        ...
# 3360097          36          109         2           42401    1  42.613199
# 3360098          36          109         2           42401    1  42.613199
# 3360099          36          109         2           42401    1  42.613199
# 3360100          36          109         2           42401    1  42.613199
# 3360101          36          109         2           42401    1  42.613199
#
#          Longitude  Datum  Parameter Name Sample Duration  ...   AQI  \
# 31916   -73.163447  NAD83  Sulfur dioxide          1 HOUR  ...  16.0
# 31917   -73.163447  NAD83  Sulfur dioxide          1 HOUR  ...  24.0
# 31918   -73.163447  NAD83  Sulfur dioxide          1 HOUR  ...  19.0
# 31919   -73.163447  NAD83  Sulfur dioxide          1 HOUR  ...  23.0
# 31920   -73.163447  NAD83  Sulfur dioxide          1 HOUR  ...  21.0
# ...            ...    ...             ...             ...  ...   ...
# 3360097 -76.615200  NAD83  Sulfur dioxide    3-HR BLK AVG  ...   NaN
# 3360098 -76.615200  NAD83  Sulfur dioxide    3-HR BLK AVG  ...   NaN
# 3360099 -76.615200  NAD83  Sulfur dioxide    3-HR BLK AVG  ...   NaN
# 3360100 -76.615200  NAD83  Sulfur dioxide    3-HR BLK AVG  ...   NaN
# 3360101 -76.615200  NAD83  Sulfur dioxide    3-HR BLK AVG  ...   NaN
#
#         Method Code                                        Method Name  \
# 31916         560.0  INSTRUMENTAL - Pulsed Fluorescent 43C-TLE/43i-TLE
# 31917         560.0  INSTRUMENTAL - Pulsed Fluorescent 43C-TLE/43i-TLE
# 31918         560.0  INSTRUMENTAL - Pulsed Fluorescent 43C-TLE/43i-TLE
# 31919         560.0  INSTRUMENTAL - Pulsed Fluorescent 43C-TLE/43i-TLE
# 31920         560.0  INSTRUMENTAL - Pulsed Fluorescent 43C-TLE/43i-TLE
# ...             ...                                                ...
# 3360097         NaN                                                 -
# 3360098         NaN                                                 -
# 3360099         NaN                                                 -
# 3360100         NaN                                                 -
# 3360101         NaN                                                 -
#
#         Local Site Name             Address   State Name  County Name  \
# 31916               NaN  115 BOSTON TERRACE  Connecticut    Fairfield
# 31917               NaN  115 BOSTON TERRACE  Connecticut    Fairfield
# 31918               NaN  115 BOSTON TERRACE  Connecticut    Fairfield
# 31919               NaN  115 BOSTON TERRACE  Connecticut    Fairfield
# 31920               NaN  115 BOSTON TERRACE  Connecticut    Fairfield
# ...                 ...                 ...          ...          ...
# 3360097     Cayuga East   134 Lake Ridge Rd     New York     Tompkins
# 3360098     Cayuga East   134 Lake Ridge Rd     New York     Tompkins
# 3360099     Cayuga East   134 Lake Ridge Rd     New York     Tompkins
# 3360100     Cayuga East   134 Lake Ridge Rd     New York     Tompkins
# 3360101     Cayuga East   134 Lake Ridge Rd     New York     Tompkins
#
#                        City Name                        CBSA Name  \
# 31916                 Bridgeport  Bridgeport-Stamford-Norwalk, CT
# 31917                 Bridgeport  Bridgeport-Stamford-Norwalk, CT
# 31918                 Bridgeport  Bridgeport-Stamford-Norwalk, CT
# 31919                 Bridgeport  Bridgeport-Stamford-Norwalk, CT
# 31920                 Bridgeport  Bridgeport-Stamford-Norwalk, CT
# ...                          ...                              ...
# 3360097  Lansing (South Lansing)                       Ithaca, NY
# 3360098  Lansing (South Lansing)                       Ithaca, NY
# 3360099  Lansing (South Lansing)                       Ithaca, NY
# 3360100  Lansing (South Lansing)                       Ithaca, NY
# 3360101  Lansing (South Lansing)                       Ithaca, NY
#
#          Date of Last Change
# 31916             2013-06-10
# 31917             2013-06-10
# 31918             2013-06-10
# 31919             2013-06-10
# 31920             2013-06-10
# ...                      ...
# 3360097           2019-10-28
# 3360098           2019-10-28
# 3360099           2019-10-28
# 3360100           2019-10-28
# 3360101           2019-10-28
#
# [272882 rows x 29 columns]

# %%
so2_data.to_csv("../Output/Summary_so2_data.csv")

# %%
co_data = co_df.loc[(co_df["State Name"]=="Connecticut")|(co_df["State Name"]=="New York")|(co_df["State Name"]=="New Jersey")&(co_df["Date Local"]>"1/1/2010")]

# %%
co_data
# Out:
#          State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 73372             9            1        10           42101    1  41.170833
# 73373             9            1        10           42101    1  41.170833
# 73374             9            1        10           42101    1  41.170833
# 73375             9            1        10           42101    1  41.170833
# 73376             9            1        10           42101    1  41.170833
# ...             ...          ...       ...             ...  ...        ...
# 2242683          36          101         3           42101    1  42.091420
# 2242684          36          101         3           42101    1  42.091420
# 2242685          36          101         3           42101    1  42.091420
# 2242686          36          101         3           42101    1  42.091420
# 2242687          36          101         3           42101    1  42.091420
#
#          Longitude  Datum   Parameter Name        Sample Duration  ...  AQI  \
# 73372   -73.194722  WGS84  Carbon monoxide                 1 HOUR  ...  NaN
# 73373   -73.194722  WGS84  Carbon monoxide                 1 HOUR  ...  NaN
# 73374   -73.194722  WGS84  Carbon monoxide                 1 HOUR  ...  NaN
# 73375   -73.194722  WGS84  Carbon monoxide                 1 HOUR  ...  NaN
# 73376   -73.194722  WGS84  Carbon monoxide                 1 HOUR  ...  NaN
# ...            ...    ...              ...                    ...  ...  ...
# 2242683 -77.209780  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...  2.0
# 2242684 -77.209780  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...  2.0
# 2242685 -77.209780  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...  1.0
# 2242686 -77.209780  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...  2.0
# 2242687 -77.209780  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...  2.0
#
#         Method Code                            Method Name  \
# 73372          54.0  INSTRUMENTAL - NONDISPERSIVE INFRARED
# 73373          54.0  INSTRUMENTAL - NONDISPERSIVE INFRARED
# 73374          54.0  INSTRUMENTAL - NONDISPERSIVE INFRARED
# 73375          54.0  INSTRUMENTAL - NONDISPERSIVE INFRARED
# 73376          54.0  INSTRUMENTAL - NONDISPERSIVE INFRARED
# ...             ...                                    ...
# 2242683         NaN                                     -
# 2242684         NaN                                     -
# 2242685         NaN                                     -
# 2242686         NaN                                     -
# 2242687         NaN                                     -
#
#                      Local Site Name                                  Address  \
# 73372    Roosevelt School-Bridgeport               ROOSEVELT SCHOOL PARK AVE.
# 73373    Roosevelt School-Bridgeport               ROOSEVELT SCHOOL PARK AVE.
# 73374    Roosevelt School-Bridgeport               ROOSEVELT SCHOOL PARK AVE.
# 73375    Roosevelt School-Bridgeport               ROOSEVELT SCHOOL PARK AVE.
# 73376    Roosevelt School-Bridgeport               ROOSEVELT SCHOOL PARK AVE.
# ...                              ...                                      ...
# 2242683          PINNACLE STATE PARK  8301 ACKERSON ROAD, Pinnacle State Park
# 2242684          PINNACLE STATE PARK  8301 ACKERSON ROAD, Pinnacle State Park
# 2242685          PINNACLE STATE PARK  8301 ACKERSON ROAD, Pinnacle State Park
# 2242686          PINNACLE STATE PARK  8301 ACKERSON ROAD, Pinnacle State Park
# 2242687          PINNACLE STATE PARK  8301 ACKERSON ROAD, Pinnacle State Park
#
#           State Name  County Name      City Name  \
# 73372    Connecticut    Fairfield     Bridgeport
# 73373    Connecticut    Fairfield     Bridgeport
# 73374    Connecticut    Fairfield     Bridgeport
# 73375    Connecticut    Fairfield     Bridgeport
# 73376    Connecticut    Fairfield     Bridgeport
# ...              ...          ...            ...
# 2242683     New York      Steuben  Not in a city
# 2242684     New York      Steuben  Not in a city
# 2242685     New York      Steuben  Not in a city
# 2242686     New York      Steuben  Not in a city
# 2242687     New York      Steuben  Not in a city
#
#                                CBSA Name  Date of Last Change
# 73372    Bridgeport-Stamford-Norwalk, CT           2016-04-11
# 73373    Bridgeport-Stamford-Norwalk, CT           2016-04-11
# 73374    Bridgeport-Stamford-Norwalk, CT           2016-04-11
# 73375    Bridgeport-Stamford-Norwalk, CT           2016-04-11
# 73376    Bridgeport-Stamford-Norwalk, CT           2016-04-11
# ...                                  ...                  ...
# 2242683                      Corning, NY           2019-10-28
# 2242684                      Corning, NY           2019-10-28
# 2242685                      Corning, NY           2019-10-28
# 2242686                      Corning, NY           2019-10-28
# 2242687                      Corning, NY           2019-10-28
#
# [158634 rows x 29 columns]

# %%
co_data.to_csv("../Output/Summary_co_data.csv")

# %%
ozone_data = ozone_df.loc[(ozone_df["State Name"]=="Connecticut")|(ozone_df["State Name"]=="New York")|(ozone_df["State Name"]=="New Jersey")&(ozone_df["Date Local"]>"1/1/2010")]

# %%
ozone_data
# Out:
#          State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 96554             9            1        17           44201    1  41.004657
# 96555             9            1        17           44201    1  41.004657
# 96556             9            1        17           44201    1  41.004657
# 96557             9            1        17           44201    1  41.004657
# 96558             9            1        17           44201    1  41.004657
# ...             ...          ...       ...             ...  ...        ...
# 4042986          36          119      2004           44201    1  41.051920
# 4042987          36          119      2004           44201    1  41.051920
# 4042988          36          119      2004           44201    1  41.051920
# 4042989          36          119      2004           44201    1  41.051920
# 4042990          36          119      2004           44201    1  41.051920
#
#          Longitude  Datum Parameter Name          Sample Duration  ...   AQI  \
# 96554   -73.585128  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  34.0
# 96555   -73.585128  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  40.0
# 96556   -73.585128  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31.0
# 96557   -73.585128  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  39.0
# 96558   -73.585128  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  39.0
# ...            ...    ...            ...                      ...  ...   ...
# 4042986 -73.763660  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  38.0
# 4042987 -73.763660  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  34.0
# 4042988 -73.763660  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  44.0
# 4042989 -73.763660  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  28.0
# 4042990 -73.763660  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  29.0
#
#         Method Code Method Name       Local Site Name  \
# 96554           NaN          -   Greenwich Point Park
# 96555           NaN          -   Greenwich Point Park
# 96556           NaN          -   Greenwich Point Park
# 96557           NaN          -   Greenwich Point Park
# 96558           NaN          -   Greenwich Point Park
# ...             ...         ...                   ...
# 4042986         NaN          -           WHITE PLAINS
# 4042987         NaN          -           WHITE PLAINS
# 4042988         NaN          -           WHITE PLAINS
# 4042989         NaN          -           WHITE PLAINS
# 4042990         NaN          -           WHITE PLAINS
#
#                                                 Address   State Name  \
# 96554                   Tods Driftway (see coordinates)  Connecticut
# 96555                   Tods Driftway (see coordinates)  Connecticut
# 96556                   Tods Driftway (see coordinates)  Connecticut
# 96557                   Tods Driftway (see coordinates)  Connecticut
# 96558                   Tods Driftway (see coordinates)  Connecticut
# ...                                                 ...          ...
# 4042986  WHITE PLAINS PUMP STATION,  240 ORCHARD STREET     New York
# 4042987  WHITE PLAINS PUMP STATION,  240 ORCHARD STREET     New York
# 4042988  WHITE PLAINS PUMP STATION,  240 ORCHARD STREET     New York
# 4042989  WHITE PLAINS PUMP STATION,  240 ORCHARD STREET     New York
# 4042990  WHITE PLAINS PUMP STATION,  240 ORCHARD STREET     New York
#
#          County Name            City Name  \
# 96554      Fairfield  Greenwich (Town of)
# 96555      Fairfield  Greenwich (Town of)
# 96556      Fairfield  Greenwich (Town of)
# 96557      Fairfield  Greenwich (Town of)
# 96558      Fairfield  Greenwich (Town of)
# ...              ...                  ...
# 4042986  Westchester         White Plains
# 4042987  Westchester         White Plains
# 4042988  Westchester         White Plains
# 4042989  Westchester         White Plains
# 4042990  Westchester         White Plains
#
#                                      CBSA Name  Date of Last Change
# 96554          Bridgeport-Stamford-Norwalk, CT           2018-07-19
# 96555          Bridgeport-Stamford-Norwalk, CT           2018-07-19
# 96556          Bridgeport-Stamford-Norwalk, CT           2018-07-19
# 96557          Bridgeport-Stamford-Norwalk, CT           2018-07-19
# 96558          Bridgeport-Stamford-Norwalk, CT           2018-07-19
# ...                                        ...                  ...
# 4042986  New York-Newark-Jersey City, NY-NJ-PA           2019-10-28
# 4042987  New York-Newark-Jersey City, NY-NJ-PA           2019-10-28
# 4042988  New York-Newark-Jersey City, NY-NJ-PA           2019-10-28
# 4042989  New York-Newark-Jersey City, NY-NJ-PA           2019-10-28
# 4042990  New York-Newark-Jersey City, NY-NJ-PA           2019-10-28
#
# [207994 rows x 29 columns]

# %%
ozone_data.to_csv("../Output/Summary_ozone_data.csv")

# %%
#Emissions DataFrame
emission_df = pd.read_csv("../Output/emissions_compiled.csv")

# %%
nata_summary = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_allhi.csv")
nata_cancer = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_cancerrisk_by_tract_poll.csv")
nata_immune = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_immuhi_by_tract_poll.csv")
nata_kidney = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_kidnhi_by_tract_poll.csv")
nata_liver = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_liverhi_by_tract_poll.csv")
nata_neuro = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_neurhi_by_tract_poll.csv")
nata_respiratory = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_resphi_by_tract_poll.csv")

# %% [markdown]
# # Analysis & Workings
